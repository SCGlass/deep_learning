# %% [markdown]
# # Network Architecture Exploration: Understanding Underfitting and Overfitting
# ## Background
# This exercise aims to demonstrate how different neural network architectures can lead to underfitting or overfitting. You will experiment with various configurations of a fully connected neural network to observe these phenomena.
#
# ## Underfitting
# Occurs when a model is too simple to capture the underlying pattern of the data. Often caused by having too few layers or neurons.
#
# ## Overfitting
# Happens when a model learns the training data too well, including the noise, making it perform poorly on new, unseen data. This can result from having too many layers or neurons.

# %% [markdown]
# ## Setup
# Import the necessary libraries and prepare the dataset.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# Generate synthetic data
X, y = make_circles(n_samples=6000, noise=0.09, factor=0.5, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()

# %% [markdown]
# # Model Building
# Define a function to create a model with a variable number of layers and neurons.

# %%
def build_model(num_layers=1, num_neurons=10, activation_function='sigmoid'):
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function, input_shape=(2,)))
    
    for _ in range(num_layers - 1):
        model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function))
        
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Train and Evaluate Model Script
# Below is a skeleton for a function to train and evaluate your models. Fill in the missing parts as indicated by the comments.

# %%
def train_and_evaluate_model(model, epochs=50, plot=True):
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2)

    # Evaluate the model on the test set
    test_loss, test_accuracy =model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

    # Plotting (if enabled)
    if plot:
        plt.figure(figsize=(12, 5))

        # Plot training and validation accuracy
        plt.subplot(1,3,1)
        plt.plot(history.history["accuracy"], label="Training Accuracy")
        plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()

        predictions = model.predict(X_test) > 0.5
        
        # Plot model predictions vs. ground truth on the test set
        plt.subplot(1, 3, 2)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm)
        plt.title('Model Predictions on Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        plt.subplot(1, 3, 3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title('Ground Truth for Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
            
        plt.show()

    # TASK: Print or return any other metrics or plots you think are necessary
    return test_loss, test_accuracy, history

# Example of using the function with a specific architecture
model = build_model(num_layers=2, num_neurons=10)
train_and_evaluate_model(model, epochs=50)
# Out:
# Test Loss: 0.6589, Test Accuracy: 0.8083
# 94/94 [==============================] - 0s 2ms/step
# (0.6589440107345581,
#  0.8083333373069763,
#  <keras.src.callbacks.History at 0x7fc577ff22c0>)

# %% [markdown]
# # Experimentation
# ## Task 1: Underfitting
# 1. Create and train a model with very few layers and/or neurons (e.g., 1 layer with 5 neurons).
# 2. Evaluate Performance:
#     * Plot training and validation accuracy over epochs.
#     * Plot model predictions vs. ground truth on the test data.
#     * Analyze if the model's performance is poor on both training and test data, which indicates underfitting.
# ## Task 2: Overfitting
# 1. Create a model with an excessive number of layers and/or neurons (e.g., 5 layers with 100 neurons each) and increased number of epochs.
# 2. Evaluate Performance:
#     * Observe the training and validation accuracy plots for a wide gap, indicating overfitting.
#     * Compare model predictions with ground truth for the test data.
#     * Look for high training accuracy but poor test accuracy.
# ## Task 3: Balanced Model
# 1. Experiment to find a balanced architecture.
# 2. Evaluate Performance:
#     * Ensure the training and validation accuracy are both high and close to each other.
#     * The model's predictions should closely match the ground truth for the test data.
#     * The model should not show signs of significant underfitting or overfitting.

# %% [markdown]
# # Evaluation and Analysis
# Use similar evaluation and visualization code as in the previous exercise to assess model performance.
# Answer questions like:
# 1. What signs of underfitting did you observe?
# 2. What were the indications of overfitting?
# 3. Describe the architecture of the balanced model and its performance.
#
# # Conclusion
# Reflect on the importance of matching model complexity with the problem complexity and discuss the trade-offs involved in designing neural network architectures.

# %%
# Task 1 - under fitting

model_under = build_model(num_layers=1, num_neurons=2)
train_and_evaluate_model(model_under, epochs=50)
# Out:
# Test Loss: 0.6891, Test Accuracy: 0.7183
# 94/94 [==============================] - 0s 2ms/step
# (0.6890660524368286,
#  0.7183333039283752,
#  <keras.src.callbacks.History at 0x7fc577ca32b0>)

# %%
# Task 2 overfitting

model_over = build_model(num_layers=5, num_neurons=100)
train_and_evaluate_model(model_over, epochs=50)
# Out:
# Test Loss: 0.6948, Test Accuracy: 0.5027
# 94/94 [==============================] - 0s 3ms/step
# (0.6947749257087708,
#  0.5026666522026062,
#  <keras.src.callbacks.History at 0x7fc577aa2410>)

# %%
# Task 3 - balanced model

model_balanced = build_model(num_layers=2, num_neurons=50)
train_and_evaluate_model(model_balanced, epochs=50)
# Out:
# Test Loss: 0.3785, Test Accuracy: 0.8260
# 94/94 [==============================] - 0s 2ms/step
# (0.3785446286201477,
#  0.8259999752044678,
#  <keras.src.callbacks.History at 0x7fc577b2bb80>)

# %% [markdown]
# ------------------

# %% [markdown]
# # Regularization Technique: Early Stopping
# ## Objective
# Understand how early stopping can be used as a regularization technique to prevent overfitting and improve the generalization of neural networks.
#
# ## Background
# Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method, such as gradient descent. It involves stopping the training process if the model's performance on a validation set starts to deteriorate, meaning the model begins to learn noise and details from the training data that negatively impact its performance on unseen data.
#
# ## How Early Stopping Works
# * Monitor the model's performance on a validation set during training.
# * If the performance on the validation set stops improving or starts to worsen, stop the training.
# * Often, a 'patience' parameter is set to allow some leeway, meaning training will stop only after the model's performance hasn't improved for a specified number of epochs.

# %% [markdown]
# # Implementation in TensorFlow
# TensorFlow provides an easy way to implement early stopping through callbacks. Here’s how you can add early stopping to your training process:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Include this callback in the model's fit method
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6556 - accuracy: 0.8029 - val_loss: 0.6507 - val_accuracy: 0.7900
# Epoch 2/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.6486 - accuracy: 0.8225 - val_loss: 0.6452 - val_accuracy: 0.8317
# Epoch 3/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.6405 - accuracy: 0.8329 - val_loss: 0.6356 - val_accuracy: 0.8400
# Epoch 4/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6313 - accuracy: 0.8375 - val_loss: 0.6269 - val_accuracy: 0.8517
# Epoch 5/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.6207 - accuracy: 0.8446 - val_loss: 0.6155 - val_accuracy: 0.8617
# Epoch 6/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.6080 - accuracy: 0.8521 - val_loss: 0.6024 - val_accuracy: 0.8667
# Epoch 7/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5943 - accuracy: 0.8742 - val_loss: 0.5906 - val_accuracy: 0.8467
# Epoch 8/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5787 - accuracy: 0.8708 - val_loss: 0.5729 - val_accuracy: 0.8767
# Epoch 9/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5611 - accuracy: 0.8946 - val_loss: 0.5539 - val_accuracy: 0.9317
# Epoch 10/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5422 - accuracy: 0.9212 - val_loss: 0.5340 - val_accuracy: 0.9483
# Epoch 11/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.9463 - val_loss: 0.5132 - val_accuracy: 0.9550
# Epoch 12/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.9554 - val_loss: 0.4929 - val_accuracy: 0.9533
# Epoch 13/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4752 - accuracy: 0.9646 - val_loss: 0.4711 - val_accuracy: 0.9533
# Epoch 14/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.9750 - val_loss: 0.4432 - val_accuracy: 0.9750
# Epoch 15/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4243 - accuracy: 0.9792 - val_loss: 0.4158 - val_accuracy: 0.9833
# Epoch 16/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.9837 - val_loss: 0.3911 - val_accuracy: 0.9833
# Epoch 17/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.9850 - val_loss: 0.3612 - val_accuracy: 0.9883
# Epoch 18/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.9862 - val_loss: 0.3380 - val_accuracy: 0.9900
# Epoch 19/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3217 - accuracy: 0.9883 - val_loss: 0.3144 - val_accuracy: 0.9900
# Epoch 20/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2983 - accuracy: 0.9896 - val_loss: 0.2918 - val_accuracy: 0.9900
# Epoch 21/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2765 - accuracy: 0.9908 - val_loss: 0.2688 - val_accuracy: 0.9917
# Epoch 22/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2562 - accuracy: 0.9917 - val_loss: 0.2498 - val_accuracy: 0.9917
# Epoch 23/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.9912 - val_loss: 0.2320 - val_accuracy: 0.9917
# Epoch 24/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2198 - accuracy: 0.9908 - val_loss: 0.2171 - val_accuracy: 0.9917
# Epoch 25/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2040 - accuracy: 0.9925 - val_loss: 0.2001 - val_accuracy: 0.9917
# Epoch 26/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1895 - accuracy: 0.9929 - val_loss: 0.1858 - val_accuracy: 0.9917
# Epoch 27/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9933 - val_loss: 0.1734 - val_accuracy: 0.9917
# Epoch 28/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9937 - val_loss: 0.1623 - val_accuracy: 0.9900
# Epoch 29/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1539 - accuracy: 0.9937 - val_loss: 0.1517 - val_accuracy: 0.9900
# Epoch 30/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9937 - val_loss: 0.1440 - val_accuracy: 0.9917
# Epoch 31/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9942 - val_loss: 0.1340 - val_accuracy: 0.9917
# Epoch 32/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 0.9942 - val_loss: 0.1268 - val_accuracy: 0.9917
# Epoch 33/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9937 - val_loss: 0.1204 - val_accuracy: 0.9917
# Epoch 34/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.9942 - val_loss: 0.1132 - val_accuracy: 0.9917
# Epoch 35/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1068 - accuracy: 0.9942 - val_loss: 0.1074 - val_accuracy: 0.9900
# Epoch 36/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9942 - val_loss: 0.1041 - val_accuracy: 0.9933
# Epoch 37/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0962 - accuracy: 0.9942 - val_loss: 0.0970 - val_accuracy: 0.9917
# Epoch 38/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0912 - accuracy: 0.9946 - val_loss: 0.0927 - val_accuracy: 0.9917
# Epoch 39/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9942 - val_loss: 0.0892 - val_accuracy: 0.9933
# Epoch 40/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9950 - val_loss: 0.0836 - val_accuracy: 0.9900
# Epoch 41/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9946 - val_loss: 0.0803 - val_accuracy: 0.9900
# Epoch 42/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9946 - val_loss: 0.0773 - val_accuracy: 0.9917
# Epoch 43/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9946 - val_loss: 0.0757 - val_accuracy: 0.9933
# Epoch 44/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9954 - val_loss: 0.0716 - val_accuracy: 0.9917
# Epoch 45/100
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0669 - accuracy: 0.9946 - val_loss: 0.0688 - val_accuracy: 0.9933
# Epoch 46/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9942 - val_loss: 0.0661 - val_accuracy: 0.9917
# Epoch 47/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9946 - val_loss: 0.0647 - val_accuracy: 0.9933
# Epoch 48/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9942 - val_loss: 0.0629 - val_accuracy: 0.9933
# Epoch 49/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9950 - val_loss: 0.0595 - val_accuracy: 0.9917
# Epoch 50/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 0.9946 - val_loss: 0.0578 - val_accuracy: 0.9933
# Epoch 51/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9950 - val_loss: 0.0565 - val_accuracy: 0.9933
# Epoch 52/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9946 - val_loss: 0.0540 - val_accuracy: 0.9933
# Epoch 53/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9950 - val_loss: 0.0531 - val_accuracy: 0.9933
# Epoch 54/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9954 - val_loss: 0.0525 - val_accuracy: 0.9933
# Epoch 55/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9946 - val_loss: 0.0494 - val_accuracy: 0.9933
# Epoch 56/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.9950 - val_loss: 0.0478 - val_accuracy: 0.9933
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9950 - val_loss: 0.0475 - val_accuracy: 0.9933
# Epoch 58/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9954 - val_loss: 0.0459 - val_accuracy: 0.9933
# Epoch 59/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9950 - val_loss: 0.0443 - val_accuracy: 0.9933
# Epoch 60/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9950 - val_loss: 0.0431 - val_accuracy: 0.9933
# Epoch 61/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9946 - val_loss: 0.0425 - val_accuracy: 0.9933
# Epoch 62/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9954 - val_loss: 0.0416 - val_accuracy: 0.9933
# Epoch 63/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9954 - val_loss: 0.0404 - val_accuracy: 0.9933
# Epoch 64/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9950 - val_loss: 0.0397 - val_accuracy: 0.9933
# Epoch 65/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9954 - val_loss: 0.0396 - val_accuracy: 0.9933
# Epoch 66/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 0.9954 - val_loss: 0.0373 - val_accuracy: 0.9933
# Epoch 67/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 0.9954 - val_loss: 0.0374 - val_accuracy: 0.9933
# Epoch 68/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 0.9950 - val_loss: 0.0361 - val_accuracy: 0.9933
# Epoch 69/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9954 - val_loss: 0.0356 - val_accuracy: 0.9933
# Epoch 70/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9954 - val_loss: 0.0351 - val_accuracy: 0.9933
# Epoch 71/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9954 - val_loss: 0.0340 - val_accuracy: 0.9933
# Epoch 72/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9954 - val_loss: 0.0332 - val_accuracy: 0.9933
# Epoch 73/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9954 - val_loss: 0.0333 - val_accuracy: 0.9933
# Epoch 74/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9950 - val_loss: 0.0321 - val_accuracy: 0.9933
# Epoch 75/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9954 - val_loss: 0.0320 - val_accuracy: 0.9933
# Epoch 76/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 0.9954 - val_loss: 0.0312 - val_accuracy: 0.9933
# Epoch 77/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9958 - val_loss: 0.0306 - val_accuracy: 0.9933
# Epoch 78/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9958 - val_loss: 0.0317 - val_accuracy: 0.9933
# Epoch 79/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9958 - val_loss: 0.0297 - val_accuracy: 0.9933
# Epoch 80/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9950 - val_loss: 0.0295 - val_accuracy: 0.9933
# Epoch 81/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9954 - val_loss: 0.0284 - val_accuracy: 0.9950
# Epoch 82/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9954 - val_loss: 0.0278 - val_accuracy: 0.9950
# Epoch 83/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9958 - val_loss: 0.0283 - val_accuracy: 0.9933
# Epoch 84/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9950 - val_loss: 0.0274 - val_accuracy: 0.9933
# Epoch 85/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9958 - val_loss: 0.0271 - val_accuracy: 0.9933
# Epoch 86/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9954 - val_loss: 0.0269 - val_accuracy: 0.9933
# Epoch 87/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9958 - val_loss: 0.0273 - val_accuracy: 0.9933
# Epoch 88/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9954 - val_loss: 0.0259 - val_accuracy: 0.9950
# Epoch 89/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9958 - val_loss: 0.0254 - val_accuracy: 0.9950
# Epoch 90/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9958 - val_loss: 0.0252 - val_accuracy: 0.9950
# Epoch 91/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9958 - val_loss: 0.0256 - val_accuracy: 0.9933
# Epoch 92/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9962 - val_loss: 0.0250 - val_accuracy: 0.9933
# Epoch 93/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9958 - val_loss: 0.0242 - val_accuracy: 0.9950
# Epoch 94/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9954 - val_loss: 0.0242 - val_accuracy: 0.9950
# Epoch 95/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9958 - val_loss: 0.0242 - val_accuracy: 0.9933
# Epoch 96/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 0.0232 - val_accuracy: 0.9950
# Epoch 97/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9962 - val_loss: 0.0242 - val_accuracy: 0.9933
# Epoch 98/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9971 - val_loss: 0.0225 - val_accuracy: 0.9950
# Epoch 99/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9971 - val_loss: 0.0231 - val_accuracy: 0.9950
# Epoch 100/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9954 - val_loss: 0.0226 - val_accuracy: 0.9950

# %% [markdown]
# ## Task
# 1. Add early stopping to your neural network training process using the above code snippet.
# 2. Experiment with different values for the patience parameter and observe how it impacts the training process and the model's performance.
#
# ## Analysis and Questions
# * How does early stopping affect the number of epochs for which your model trains?
# * Did you observe any improvements in the generalization of your model to the test data?
# * How does the patience parameter impact the effectiveness of early stopping?
#
# ## Conclusion
# Reflect on the importance of regularization techniques like early stopping in preventing overfitting and improving model generalization.

# %%
import keras.backend as K

# %%
def train_and_evaluate_model_early_stop(model, epochs=50,patience=10, plot=True):
    
    K.set_learning_phase(1)
   
    # adding early stopping
    early_stopping_test = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True, verbose=1)
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2, callbacks=[early_stopping_test])
    

    # Evaluate the model on the test set
    test_loss, test_accuracy =model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

    # Plotting (if enabled)
    if plot:
        plt.figure(figsize=(12, 5))

        # Plot training and validation accuracy
        plt.subplot(1,3,1)
        plt.plot(history.history["accuracy"], label="Training Accuracy")
        plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()

        predictions = model.predict(X_test) > 0.5
        
        # Plot model predictions vs. ground truth on the test set
        plt.subplot(1, 3, 2)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm)
        plt.title('Model Predictions on Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        plt.subplot(1, 3, 3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title('Ground Truth for Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
            
        plt.show()

    # TASK: Print or return any other metrics or plots you think are necessary
    return  test_loss, test_accuracy, history, early_stopping_test

# %%
model_early = build_model(num_layers=2, num_neurons=50)
train_and_evaluate_model_early_stop(model_early, epochs=100,patience=15)
# Out:
# /home/sam_glass/deep_learning/venv/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Restoring model weights from the end of the best epoch: 15.
# Epoch 30: early stopping
# Test Loss: 0.6973, Test Accuracy: 0.4973
# 94/94 [==============================] - 0s 2ms/step
# (0.6973121762275696,
#  0.4973333477973938,
#  <keras.src.callbacks.History at 0x7fc591c3d210>,
#  <keras.src.callbacks.EarlyStopping at 0x7fc591e10df0>)

# %%
model_early_2 = build_model(num_layers=2, num_neurons=50)
train_and_evaluate_model_early_stop(model_early_2, epochs=100,patience=50)
# Out:
# Test Loss: 0.0149, Test Accuracy: 0.9970
# 94/94 [==============================] - 0s 2ms/step
# (0.01491827517747879,
#  0.996999979019165,
#  <keras.src.callbacks.History at 0x7fc5918ad390>,
#  <keras.src.callbacks.EarlyStopping at 0x7fc591e25cf0>)
